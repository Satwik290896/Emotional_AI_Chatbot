# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! ls
# !nvidia-smi
# Out:
# drive  sample_data
# Sat May  7 04:58:09 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# cd content/drive/MyDrive/cifar10_resnet
# Out:
# [Errno 2] No such file or directory: 'content/drive/MyDrive/cifar10_resnet'
# /content/drive/.shortcut-targets-by-id/1c2LSqs3KLPC0GItMw4Fbh9nCUbujuKG_/cifar10_resnet

# %%
import csv
import numpy as np
# !pip install emoji
import emoji
import pandas as pd
import matplotlib.pyplot as plt
#from sklearn.metrics import confusion_matrix

def read_glove_vecs(glove_file):
    with open(glove_file, 'r', encoding="UTF-8") as f:
        words = set()
        word_to_vec_map = {}
        for line in f:
            line = line.strip().split()
            curr_word = line[0]
            words.add(curr_word)
            word_to_vec_map[curr_word] = np.array(line[1:], dtype=np.float64)
        
        i = 1
        words_to_index = {}
        index_to_words = {}
        for w in sorted(words):
            words_to_index[w] = i
            index_to_words[i] = w
            i = i + 1
    return words_to_index, index_to_words, word_to_vec_map

def softmax(x):
    """Compute softmax values for each sets of scores in x."""
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum()


def read_csv(filename = 'emojify_data.csv'):
    phrase = []
    emoji = []

    with open (filename) as csvDataFile:
        csvReader = csv.reader(csvDataFile)

        for row in csvReader:
            phrase.append(row[0])
            emoji.append(row[1])

    X = np.asarray(phrase)
    Y = np.asarray(emoji, dtype=int)

    return X, Y

def convert_to_one_hot(Y, C):
    Y = np.eye(C)[Y.reshape(-1)]
    return Y


emoji_dictionary = {"0": "\u2764\uFE0F",    # :heart: prints a black instead of red heart depending on the font
                    "1": ":baseball:",
                    "2": ":smile:",
                    "3": ":disappointed:",
                    "4": ":fork_and_knife:"}

def label_to_emoji(label):
    """
    Converts a label (int or string) into the corresponding emoji code (string) ready to be printed
    """
    return emoji.emojize(emoji_dictionary[str(label)], use_aliases=True)
              
    
def print_predictions(X, pred):
    print()
    for i in range(X.shape[0]):
        print(X[i], label_to_emoji(int(pred[i])))
        
        
def plot_confusion_matrix(y_actu, y_pred, title='Confusion matrix', cmap=plt.cm.gray_r):
    
    df_confusion = pd.crosstab(y_actu, y_pred.reshape(y_pred.shape[0],), rownames=['Actual'], colnames=['Predicted'], margins=True)
    
    df_conf_norm = df_confusion / df_confusion.sum(axis=1)
    
    plt.matshow(df_confusion, cmap=cmap) # imshow
    #plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(df_confusion.columns))
    plt.xticks(tick_marks, df_confusion.columns, rotation=45)
    plt.yticks(tick_marks, df_confusion.index)
    #plt.tight_layout()
    plt.ylabel(df_confusion.index.name)
    plt.xlabel(df_confusion.columns.name)
    
    
def predict(X, Y, W, b, word_to_vec_map):
    """
    Given X (sentences) and Y (emoji indices), predict emojis and compute the accuracy of your model over the given set.
    
    Arguments:
    X -- input data containing sentences, numpy array of shape (m, None)
    Y -- labels, containing index of the label emoji, numpy array of shape (m, 1)
    
    Returns:
    pred -- numpy array of shape (m, 1) with your predictions
    """
    m = X.shape[0]
    pred = np.zeros((m, 1))
    
    for j in range(m):                       # Loop over training examples
        
        # Split jth test example (sentence) into list of lower case words
        words = X[j].lower().split()
        
        # Average words' vectors
        avg = np.zeros((50,))
        for w in words:
            avg += word_to_vec_map[w]
        avg = avg/len(words)

        # Forward propagation
        Z = np.dot(W, avg) + b
        A = softmax(Z)
        pred[j] = np.argmax(A)
        
    print("Accuracy: "  + str(np.mean((pred[:] == Y.reshape(Y.shape[0],1)[:]))))
    
    return pred
# Out:
# Collecting emoji
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#      |████████████████████████████████| 175 kB 8.0 MB/s
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171046 sha256=0f3161c3510c1e5db411bc30f006374f202ef24bb267911aa41beb29f9f8169e
#   Stored in directory: /root/.cache/pip/wheels/8a/4e/b6/57b01db010d17ef6ea9b40300af725ef3e210cb1acfb7ac8b6
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-1.7.0

# %%
import numpy as np
from keras.models import Model
from keras.layers import Dense, Input, Dropout, LSTM, Activation
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
from keras.initializers import glorot_uniform
import time
import json
# from /content/drive/MyDrive/Emotional_AI_Chatbot/emo_utils.py import *

np.random.seed(1)

def sentences_to_indices(X, word_to_index, max_len):
    """
    Converts an array of sentences (strings) into an array of indices corresponding to words in the sentences.
    The output shape should be such that it can be given to `Embedding()`

    Arguments:
    X -- array of sentences (strings), of shape (m, 1)
    word_to_index -- a dictionary containing the each word mapped to its index
    max_len -- maximum number of words in a sentence. You can assume every sentence in X is no longer than this.

    Returns:
    X_indices -- array of indices corresponding to words in the sentences from X, of shape (m, max_len)
    """

    m = X.shape[0]  # number of training examples
    # Initialize X_indices as a numpy matrix of zeros and the correct shape (≈ 1 line)
    X_indices = np.zeros((m, max_len))

    for i in range(m):  # loop over training examples
        # Convert the ith training sentence in lower case and split is into words. You should get a list of words.
        sentence_words = (X[i].lower()).split()
        # Initialize j to 0
        j = 0
        # Loop over the words of sentence_words
        for w in sentence_words:
            # Set the (i,j)th entry of X_indices to the index of the correct word.
            X_indices[i, j] = word_to_index[w]
            # Increment j to j + 1
            j = j + 1
    return X_indices

def pretrained_embedding_layer(word_to_vec_map, word_to_index):
    """
    Creates a Keras Embedding() layer and loads in pre-trained GloVe 50-dimensional vectors.

    Arguments:
    word_to_vec_map -- dictionary mapping words to their GloVe vector representation.
    word_to_index -- dictionary mapping from words to their indices in the vocabulary (400,001 words)

    Returns:
    embedding_layer -- pretrained layer Keras instance
    """
    vocab_len = len(word_to_index) + 1  # adding 1 to fit Keras embedding (requirement)
    emb_dim = word_to_vec_map["cucumber"].shape[0]  # define dimensionality of your GloVe word vectors (= 50)

    # Initialize the embedding matrix as a numpy array of zeros of shape (vocab_len, dimensions of word vectors = emb_dim)
    emb_matrix = np.zeros((vocab_len, emb_dim))

    # Set each row "index" of the embedding matrix to be the word vector representation of the "index"th word of the vocabulary
    for word, index in word_to_index.items():
        emb_matrix[index, :] = word_to_vec_map[word]

    # Define Keras embedding layer with the correct output/input sizes, make it trainable. Use Embedding(...). Make sure to set trainable=False.
    embedding_layer = Embedding(vocab_len, emb_dim)

    # Build the embedding layer, it is required before setting the weights of the embedding layer. Do not modify the "None".
    embedding_layer.build((None,))

    # Set the weights of the embedding layer to the embedding matrix. Your layer is now pretrained.
    embedding_layer.set_weights([emb_matrix])

    return embedding_layer


def SentimentAnalysis(input_shape, word_to_vec_map, word_to_index):
    """
    Function creating the Emojify-v2 model's graph.

    Arguments:
    input_shape -- shape of the input, usually (max_len,)
    word_to_vec_map -- dictionary mapping every word in a vocabulary into its 50-dimensional vector representation
    word_to_index -- dictionary mapping from words to their indices in the vocabulary (400,001 words)

    Returns:
    model -- a model instance in Keras
    """
    # Define sentence_indices as the input of the graph, it should be of shape input_shape and dtype 'int32' (as it contains indices).
    sentence_indices = Input(shape=input_shape, dtype=np.int32)

    # Create the embedding layer pretrained with GloVe Vectors (≈1 line)
    embedding_layer = pretrained_embedding_layer(word_to_vec_map, word_to_index)

    # Propagate sentence_indices through your embedding layer, you get back the embeddings
    embeddings = embedding_layer(sentence_indices)
    
    # Rohan addition:
    embeddings.trainable = False

    # Propagate the embeddings through an LSTM layer with 128-dimensional hidden state
    # Be careful, the returned output should be a batch of sequences.
    X = LSTM(128, return_sequences=True)(embeddings)
    # Add dropout with a probability of 0.5
    X = Dropout(0.5)(X)
    # Propagate X trough another LSTM layer with 128-dimensional hidden state
    # Be careful, the returned output should be a single hidden state, not a batch of sequences.
    X = LSTM(128)(X)
    # Add dropout with a probability of 0.5
    X = Dropout(0.5)(X)
    # Propagate X through a Dense layer with softmax activation to get back a batch of 5-dimensional vectors.
    X = Dense(5, activation='softmax')(X)
    # Add a softmax activation
    X = Activation('softmax')(X)

    # Create Model instance which converts sentence_indices into X.
    model = Model(sentence_indices, X)

    return model


if __name__ == "__main__":
    # Read train and test files
    X_train, Y_train = read_csv('/content/drive/MyDrive/Emotional_AI_Chatbot/TrainDataTrim.csv')
    X_test, Y_test = read_csv('/content/drive/MyDrive/Emotional_AI_Chatbot/TestDataTrim.csv')
    maxLen = len(max(X_train, key=len).split())

    # Convert one-hot-encoding type, classification =5, [1,0,0,0,0]
    Y_oh_train = convert_to_one_hot(Y_train, C=5)
    Y_oh_test = convert_to_one_hot(Y_test, C=5)

    # Read 50 feature dimension glove file
    word_to_index, index_to_word, word_to_vec_map = read_glove_vecs('/content/drive/MyDrive/Emotional_AI_Chatbot/glove.6B.50d.txt')

    outputFileBackup = '/content/drive/MyDrive/Emotional_AI_Chatbot/hyp_search.txt'
    outputFile = '/content/drive/MyDrive/Emotional_AI_Chatbot/hyp_search.csv'
    with open(outputFile,"w") as file:
      writer = csv.writer(file)
      writer.writerow(["Loss Function","Batch Size","Optimizer","Time to Train","Loss","Test Accuracy"])

    j = 2 # For enumerating saved plots to match their rows in csv file
    for lossFxn in ["categorical_crossentropy"]:
      for optimizer in ["adam","RMSprop","Adadelta","Nadam"]:
        for batch_size in [8,16,32,64]:
          # Model and model summmary
          model = SentimentAnalysis((maxLen,), word_to_vec_map, word_to_index)
          model.summary()

          model.compile(loss=lossFxn, optimizer=optimizer, metrics=['accuracy']) # R
          # model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

          X_train_indices = sentences_to_indices(X_train, word_to_index, maxLen)
          Y_train_oh = convert_to_one_hot(Y_train, C=5)

          # Train model
          t0 = time.time()
          history = model.fit(X_train_indices, Y_train_oh, epochs=150, batch_size=batch_size, shuffle=True)
          t1 = time.time()
          timeToTrain = t1-t0

          X_test_indices = sentences_to_indices(X_test, word_to_index, max_len=maxLen)
          Y_test_oh = convert_to_one_hot(Y_test, C=5)

          # Evaluate model, loss and accuracy
          loss, acc = model.evaluate(X_test_indices, Y_test_oh)
          print()
          print("Test accuracy = ", acc)

          with open(outputFile,"a",newline='') as file:
            writer = csv.writer(file)
            writer.writerow([lossFxn,batch_size,optimizer,timeToTrain,loss,acc])

          # writer.writerow([lossFxn,batch_size,optimizer,timeToTrain,loss,acc])
          # print("Written.")

          # with open(outputFileBackup,"w") as backupFile:
          #   backupFile.write(json.dumps([lossFxn,batch_size,optimizer,timeToTrain,loss,acc]))

          # Compare prediction and expected emoji
          C = 5
          y_test_oh = np.eye(C)[Y_test.reshape(-1)]
          X_test_indices = sentences_to_indices(X_test, word_to_index, maxLen)
          pred = model.predict(X_test_indices)
          for i in range(len(X_test)):
              x = X_test_indices
              num = np.argmax(pred[i])
              if (num != Y_test[i]):
                  print('Expected emoji:' + label_to_emoji(Y_test[i]) + ' prediction: ' + X_test[i] + label_to_emoji(num).strip())

          # Test your sentence
          x_test = np.array(['I am very happy'])
          X_test_indices = sentences_to_indices(x_test, word_to_index, maxLen)
          print(x_test[0] + ' ' + label_to_emoji(np.argmax(model.predict(X_test_indices))))
          
          # Plotting results
          # print(history.history.keys())
          fig, axs = plt.subplots(1, 2)
          axs[0].plot(range(1,len(history.history['accuracy'])+1),history.history['accuracy'])
          axs[0].set_title(f'Acc - {lossFxn[:3]},{batch_size},{optimizer}')
          axs[1].plot(range(1,len(history.history['loss'])+1),history.history['loss'],'tab:red')
          axs[1].set_title(f'Loss - {lossFxn[:3]},{batch_size},{optimizer}')
          # axs[0, 0].plot(range(1,len(history.history['accuracy'])+1),history.history['accuracy'])
          # axs[0, 0].set_title('Train dataset Accuracy for BatchSize:%d' %batch_size)
          # axs[1, 0].plot(range(1,len(history.history['loss'])+1),history.history['loss'],'tab:red')
          # axs[1, 0].set_title('Training Loss for BatchSize:%d' %batch_size)
          # axs[0, 1].plot(range(1,len(history.history['val_accuracy'])+1),history.history['val_accuracy'])
          # axs[0, 1].set_title('Validation dataset Accuracy for BatchSize:%d' %batch_size)
          # axs[1, 1].plot(range(1,len(history.history['val_loss'])+1),history.history['val_loss'],'tab:red')
          # axs[1, 1].set_title('Validation Loss for BatchSize:%d' %batch_size)
          
          '''axs[0, 0].plot(history.history['accuracy'])
          axs[0, 0].set_title('Train dataset Accuracy')
          axs[0, 1].plot(history.history['loss'])
          axs[0, 1].set_title('Training Loss')
          axs[1, 0].plot(history.history['val_accuracy'])
          axs[1, 0].set_title('Validation dataset Accuracy')
          axs[1, 1].plot(history.history['val_loss'])
          axs[1, 1].set_title('Validation Loss')'''
          for ax in axs.flat:
              ax.set(xlabel='Epochs', ylabel='Parameter')

          # Hide x labels and tick labels for top plots and y ticks for right plots.
          '''for ax in axs.flat:
              ax.label_outer()'''
          plt.savefig(f"/content/drive/MyDrive/Emotional_AI_Chatbot/plots/Row{j}.png")
          j+=1
          plt.show()
# Out:
# Model: "model_56"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_58 (InputLayer)       [(None, 22)]              0
#
#  embedding_56 (Embedding)    (None, 22, 50)            20000050
#
#  lstm_112 (LSTM)             (None, 22, 128)           91648
#
#  dropout_112 (Dropout)       (None, 22, 128)           0
#
#  lstm_113 (LSTM)             (None, 128)               131584
#
#  dropout_113 (Dropout)       (None, 128)               0
#
#  dense_56 (Dense)            (None, 5)                 645
#
#  activation_56 (Activation)  (None, 5)                 0
#
# =================================================================
# Total params: 20,223,927
# Trainable params: 20,223,927
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 25/25 [==============================] - 3s 17ms/step - loss: 1.6063 - accuracy: 0.1950
# Epoch 2/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.5461 - accuracy: 0.3200
# Epoch 3/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.6180 - accuracy: 0.2050
# Epoch 4/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.5334 - accuracy: 0.3450
# Epoch 5/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.5129 - accuracy: 0.3300
# Epoch 6/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.5045 - accuracy: 0.3500
# Epoch 7/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.3861 - accuracy: 0.5500
# Epoch 8/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.4333 - accuracy: 0.4600
# Epoch 9/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.3759 - accuracy: 0.5000
# Epoch 10/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.4344 - accuracy: 0.4500
# Epoch 11/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.4876 - accuracy: 0.4150
# Epoch 12/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.5965 - accuracy: 0.3050
# Epoch 13/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.5916 - accuracy: 0.3250
# Epoch 14/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.5734 - accuracy: 0.3200
# Epoch 15/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.4369 - accuracy: 0.4550
# Epoch 16/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.4066 - accuracy: 0.5000
# Epoch 17/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.3905 - accuracy: 0.5050
# Epoch 18/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.4282 - accuracy: 0.4750
# Epoch 19/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.3916 - accuracy: 0.4950
# Epoch 20/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.3220 - accuracy: 0.5750
# Epoch 21/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.2890 - accuracy: 0.6200
# Epoch 22/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.2726 - accuracy: 0.6350
# Epoch 23/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.3000 - accuracy: 0.6100
# Epoch 24/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.5444 - accuracy: 0.3600
# Epoch 25/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.6512 - accuracy: 0.2250
# Epoch 26/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.6115 - accuracy: 0.2400
# Epoch 27/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.5999 - accuracy: 0.2150
# Epoch 28/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.5886 - accuracy: 0.2400
# Epoch 29/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.5927 - accuracy: 0.2100
# Epoch 30/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.6026 - accuracy: 0.2250
# Epoch 31/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.5978 - accuracy: 0.2300
# Epoch 32/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.5838 - accuracy: 0.2600
# Epoch 33/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.6058 - accuracy: 0.2000
# Epoch 34/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.5987 - accuracy: 0.1850
# Epoch 35/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.6015 - accuracy: 0.2050
# Epoch 36/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.5905 - accuracy: 0.2300
# Epoch 37/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.5949 - accuracy: 0.2100
# Epoch 38/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.5902 - accuracy: 0.2450
# Epoch 39/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.5993 - accuracy: 0.1900
# Epoch 40/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.5895 - accuracy: 0.2650
# Epoch 41/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.5949 - accuracy: 0.2500
# Epoch 42/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.5554 - accuracy: 0.2750
# Epoch 43/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.4502 - accuracy: 0.4550
# Epoch 44/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.4540 - accuracy: 0.4450
# Epoch 45/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.4265 - accuracy: 0.4600
# Epoch 46/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.3694 - accuracy: 0.5000
# Epoch 47/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.2781 - accuracy: 0.6150
# Epoch 48/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.2765 - accuracy: 0.6150
# Epoch 49/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.3173 - accuracy: 0.5900
# Epoch 50/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.2401 - accuracy: 0.6700
# Epoch 51/150
# 25/25 [==============================] - 1s 22ms/step - loss: 1.2324 - accuracy: 0.6750
# Epoch 52/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.2742 - accuracy: 0.6350
# Epoch 53/150
# 25/25 [==============================] - 1s 21ms/step - loss: 1.2666 - accuracy: 0.6400
# Epoch 54/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.2770 - accuracy: 0.6300
# Epoch 55/150
# 25/25 [==============================] - 1s 22ms/step - loss: 1.2354 - accuracy: 0.6650
# Epoch 56/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.2330 - accuracy: 0.6750
# Epoch 57/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.2167 - accuracy: 0.6900
# Epoch 58/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.2095 - accuracy: 0.6950
# Epoch 59/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.2004 - accuracy: 0.7050
# Epoch 60/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.1999 - accuracy: 0.7050
# Epoch 61/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.1975 - accuracy: 0.7050
# Epoch 62/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.2069 - accuracy: 0.7000
# Epoch 63/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.2455 - accuracy: 0.6600
# Epoch 64/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.2583 - accuracy: 0.6400
# Epoch 65/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.2462 - accuracy: 0.6500
# Epoch 66/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.2216 - accuracy: 0.6750
# Epoch 67/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.1922 - accuracy: 0.7100
# Epoch 68/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.2591 - accuracy: 0.6500
# Epoch 69/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.2749 - accuracy: 0.6200
# Epoch 70/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.3310 - accuracy: 0.5700
# Epoch 71/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.2258 - accuracy: 0.6700
# Epoch 72/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.2123 - accuracy: 0.6900
# Epoch 73/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.2239 - accuracy: 0.6850
# Epoch 74/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.2114 - accuracy: 0.7000
# Epoch 75/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.2309 - accuracy: 0.6750
# Epoch 76/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.2234 - accuracy: 0.6800
# Epoch 77/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.2203 - accuracy: 0.6850
# Epoch 78/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.3068 - accuracy: 0.6000
# Epoch 79/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.4873 - accuracy: 0.4100
# Epoch 80/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.3274 - accuracy: 0.5700
# Epoch 81/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.2872 - accuracy: 0.6000
# Epoch 82/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.2296 - accuracy: 0.6800
# Epoch 83/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.2293 - accuracy: 0.6700
# Epoch 84/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.2204 - accuracy: 0.6900
# Epoch 85/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.1405 - accuracy: 0.7700
# Epoch 86/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.1197 - accuracy: 0.7750
# Epoch 87/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.1169 - accuracy: 0.7850
# Epoch 88/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.2198 - accuracy: 0.6900
# Epoch 89/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.3129 - accuracy: 0.5850
# Epoch 90/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.2860 - accuracy: 0.6100
# Epoch 91/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.2934 - accuracy: 0.6150
# Epoch 92/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.2780 - accuracy: 0.6250
# Epoch 93/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.2453 - accuracy: 0.6450
# Epoch 94/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.1766 - accuracy: 0.7450
# Epoch 95/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.1936 - accuracy: 0.7050
# Epoch 96/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.1382 - accuracy: 0.7700
# Epoch 97/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.1546 - accuracy: 0.7500
# Epoch 98/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.1325 - accuracy: 0.7750
# Epoch 99/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.2273 - accuracy: 0.6800
# Epoch 100/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.3260 - accuracy: 0.5700
# Epoch 101/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.3428 - accuracy: 0.5600
# Epoch 102/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.3798 - accuracy: 0.5200
# Epoch 103/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.3361 - accuracy: 0.5550
# Epoch 104/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.3021 - accuracy: 0.5700
# Epoch 105/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.2416 - accuracy: 0.6350
# Epoch 106/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.2409 - accuracy: 0.6600
# Epoch 107/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.1879 - accuracy: 0.7100
# Epoch 108/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.2440 - accuracy: 0.6800
# Epoch 109/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.3143 - accuracy: 0.5850
# Epoch 110/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.2916 - accuracy: 0.6100
# Epoch 111/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.2719 - accuracy: 0.6200
# Epoch 112/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.2654 - accuracy: 0.6350
# Epoch 113/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.2723 - accuracy: 0.6300
# Epoch 114/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.2207 - accuracy: 0.6850
# Epoch 115/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.2311 - accuracy: 0.6650
# Epoch 116/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.1952 - accuracy: 0.7100
# Epoch 117/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.1914 - accuracy: 0.7050
# Epoch 118/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.1504 - accuracy: 0.7650
# Epoch 119/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.0810 - accuracy: 0.8200
# Epoch 120/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.0627 - accuracy: 0.8450
# Epoch 121/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.0599 - accuracy: 0.8500
# Epoch 122/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.0662 - accuracy: 0.8450
# Epoch 123/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.0519 - accuracy: 0.8600
# Epoch 124/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.0581 - accuracy: 0.8500
# Epoch 125/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.0435 - accuracy: 0.8600
# Epoch 126/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.1287 - accuracy: 0.7750
# Epoch 127/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.1512 - accuracy: 0.7600
# Epoch 128/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.1235 - accuracy: 0.7850
# Epoch 129/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.0798 - accuracy: 0.8250
# Epoch 130/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.0474 - accuracy: 0.8600
# Epoch 131/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.0319 - accuracy: 0.8750
# Epoch 132/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.0191 - accuracy: 0.8850
# Epoch 133/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.0080 - accuracy: 0.8950
# Epoch 134/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.0108 - accuracy: 0.8950
# Epoch 135/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.0252 - accuracy: 0.8850
# Epoch 136/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.0209 - accuracy: 0.8850
# Epoch 137/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.0210 - accuracy: 0.8850
# Epoch 138/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.0407 - accuracy: 0.8650
# Epoch 139/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.0548 - accuracy: 0.8500
# Epoch 140/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.1602 - accuracy: 0.7450
# Epoch 141/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.1861 - accuracy: 0.7200
# Epoch 142/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.1798 - accuracy: 0.7250
# Epoch 143/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.1652 - accuracy: 0.7400
# Epoch 144/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.1705 - accuracy: 0.7350
# Epoch 145/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.1463 - accuracy: 0.7550
# Epoch 146/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.0399 - accuracy: 0.8650
# Epoch 147/150
# 25/25 [==============================] - 0s 17ms/step - loss: 0.9953 - accuracy: 0.9100
# Epoch 148/150
# 25/25 [==============================] - 0s 17ms/step - loss: 1.0003 - accuracy: 0.9050
# Epoch 149/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.0133 - accuracy: 0.8950
# Epoch 150/150
# 25/25 [==============================] - 0s 16ms/step - loss: 1.0377 - accuracy: 0.8650
# 7/7 [==============================] - 1s 5ms/step - loss: 1.0134 - accuracy: 0.8900
#
# Test accuracy =  0.8899999856948853
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:65: DeprecationWarning: The parameter 'use_aliases' in emoji.emojize() is deprecated and will be removed in version 2.0.0. Use language='alias' instead.
# To hide this warning, pin/downgrade the package to 'emoji~=1.6.3'
# Expected emoji:❤️ prediction: What is the matter with them⚾
# Expected emoji:❤️ prediction: Where on earth is he⚾
# Expected emoji:❤️ prediction: What is he thinking⚾
# Expected emoji:❤️ prediction: What is wrong with them⚾
# Expected emoji:⚾ prediction: Why do I have so much work to do❤️
# Expected emoji:⚾ prediction: What are those noises❤️
# Expected emoji:⚾ prediction: What if she embarrasses me in front of everyone❤️
# Expected emoji:⚾ prediction: Did I offend her with my questions❤️
# Expected emoji:😄 prediction: Do you think you can stop me⚾
# Expected emoji:😄 prediction: What exciting things does today have in store for me🍴
# Expected emoji:😄 prediction: Do you want to bet⚾
# Expected emoji:😄 prediction: I am happy with the paper I turned in🍴
# Expected emoji:😄 prediction: Looking back on it and I am proud of a lot of my past🍴
# Expected emoji:😄 prediction: No one can stand in the way of my goals⚾
# Expected emoji:😞 prediction: I cannot wait for our vacation😄
# Expected emoji:😞 prediction: I am almost worried that he is going to faint when he sees the gift that he has wanted for so long😄
# Expected emoji:😞 prediction: We are getting married❤️
# Expected emoji:🍴 prediction: Why can they not just leave me alone❤️
# Expected emoji:🍴 prediction: Why can I not just be happy⚾
# Expected emoji:🍴 prediction: My favorite TV show just got canceled😞
# Expected emoji:🍴 prediction: Why am I so useless⚾
# Expected emoji:🍴 prediction: Who cares what I think❤️
# I am very happy 😄
# Model: "model_57"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_59 (InputLayer)       [(None, 22)]              0
#
#  embedding_57 (Embedding)    (None, 22, 50)            20000050
#
#  lstm_114 (LSTM)             (None, 22, 128)           91648
#
#  dropout_114 (Dropout)       (None, 22, 128)           0
#
#  lstm_115 (LSTM)             (None, 128)               131584
#
#  dropout_115 (Dropout)       (None, 128)               0
#
#  dense_57 (Dense)            (None, 5)                 645
#
#  activation_57 (Activation)  (None, 5)                 0
#
# =================================================================
# Total params: 20,223,927
# Trainable params: 20,223,927
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 13/13 [==============================] - 3s 19ms/step - loss: 1.6073 - accuracy: 0.2250
# Epoch 2/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.5719 - accuracy: 0.3200
# Epoch 3/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.5057 - accuracy: 0.4200
# Epoch 4/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.4150 - accuracy: 0.4800
# Epoch 5/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.4217 - accuracy: 0.4600
# Epoch 6/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.3838 - accuracy: 0.5150
# Epoch 7/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.3691 - accuracy: 0.5400
# Epoch 8/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.4420 - accuracy: 0.4600
# Epoch 9/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.3566 - accuracy: 0.5350
# Epoch 10/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.3401 - accuracy: 0.5700
# Epoch 11/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.3249 - accuracy: 0.5700
# Epoch 12/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.3087 - accuracy: 0.5950
# Epoch 13/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.2972 - accuracy: 0.6000
# Epoch 14/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.3064 - accuracy: 0.6000
# Epoch 15/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.2975 - accuracy: 0.6100
# Epoch 16/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.5420 - accuracy: 0.3550
# Epoch 17/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.5951 - accuracy: 0.3000
# Epoch 18/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.5700 - accuracy: 0.3250
# Epoch 19/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.5447 - accuracy: 0.3450
# Epoch 20/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.5219 - accuracy: 0.3650
# Epoch 21/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.4731 - accuracy: 0.4200
# Epoch 22/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.4541 - accuracy: 0.4550
# Epoch 23/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.4691 - accuracy: 0.4300
# Epoch 24/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.4585 - accuracy: 0.4400
# Epoch 25/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.4301 - accuracy: 0.4700
# Epoch 26/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.4413 - accuracy: 0.4550
# Epoch 27/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.3690 - accuracy: 0.5250
# Epoch 28/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.2580 - accuracy: 0.6550
# Epoch 29/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.3470 - accuracy: 0.5550
# Epoch 30/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.4709 - accuracy: 0.4350
# Epoch 31/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.3970 - accuracy: 0.5100
# Epoch 32/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.4543 - accuracy: 0.4500
# Epoch 33/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.5592 - accuracy: 0.3300
# Epoch 34/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.5246 - accuracy: 0.3450
# Epoch 35/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.4498 - accuracy: 0.4300
# Epoch 36/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.4280 - accuracy: 0.4650
# Epoch 37/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.3980 - accuracy: 0.4950
# Epoch 38/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.3847 - accuracy: 0.5200
# Epoch 39/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.3431 - accuracy: 0.5750
# Epoch 40/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.3299 - accuracy: 0.5800
# Epoch 41/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.3091 - accuracy: 0.6000
# Epoch 42/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.3136 - accuracy: 0.5950
# Epoch 43/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.4003 - accuracy: 0.4950
# Epoch 44/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.4154 - accuracy: 0.4800
# Epoch 45/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.3250 - accuracy: 0.5650
# Epoch 46/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.2934 - accuracy: 0.6300
# Epoch 47/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.2629 - accuracy: 0.6400
# Epoch 48/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.2411 - accuracy: 0.6800
# Epoch 49/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.2414 - accuracy: 0.6700
# Epoch 50/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.2245 - accuracy: 0.6900
# Epoch 51/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.2349 - accuracy: 0.6700
# Epoch 52/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.3666 - accuracy: 0.5400
# Epoch 53/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.4601 - accuracy: 0.4350
# Epoch 54/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.3715 - accuracy: 0.5200
# Epoch 55/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.3287 - accuracy: 0.5750
# Epoch 56/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.2881 - accuracy: 0.6150
# Epoch 57/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.2193 - accuracy: 0.7000
# Epoch 58/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.2012 - accuracy: 0.6950
# Epoch 59/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.1721 - accuracy: 0.7350
# Epoch 60/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.1642 - accuracy: 0.7450
# Epoch 61/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.1537 - accuracy: 0.7550
# Epoch 62/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.1229 - accuracy: 0.7850
# Epoch 63/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.1155 - accuracy: 0.7950
# Epoch 64/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.1131 - accuracy: 0.8000
# Epoch 65/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.1158 - accuracy: 0.7950
# Epoch 66/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.1125 - accuracy: 0.7950
# Epoch 67/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.1082 - accuracy: 0.8050
# Epoch 68/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.1060 - accuracy: 0.8000
# Epoch 69/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.1035 - accuracy: 0.8050
# Epoch 70/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.0903 - accuracy: 0.8150
# Epoch 71/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.0916 - accuracy: 0.8200
# Epoch 72/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.0843 - accuracy: 0.8200
# Epoch 73/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.1402 - accuracy: 0.7700
# Epoch 74/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.6113 - accuracy: 0.2900
# Epoch 75/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.5371 - accuracy: 0.3650
# Epoch 76/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.4638 - accuracy: 0.4250
# Epoch 77/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.4161 - accuracy: 0.4850
# Epoch 78/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.4446 - accuracy: 0.4550
# Epoch 79/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.4283 - accuracy: 0.4750
# Epoch 80/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.3952 - accuracy: 0.5050
# Epoch 81/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.4600 - accuracy: 0.4350
# Epoch 82/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.3820 - accuracy: 0.5250
# Epoch 83/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.3692 - accuracy: 0.5350
# Epoch 84/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.4455 - accuracy: 0.4550
# Epoch 85/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.4583 - accuracy: 0.4400
# Epoch 86/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.3771 - accuracy: 0.5250
# Epoch 87/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.3971 - accuracy: 0.5050
# Epoch 88/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.3545 - accuracy: 0.5500
# Epoch 89/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.4205 - accuracy: 0.4800
# Epoch 90/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.3669 - accuracy: 0.5350
# Epoch 91/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.3914 - accuracy: 0.5100
# Epoch 92/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.3656 - accuracy: 0.5400
# Epoch 93/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.3568 - accuracy: 0.5450
# Epoch 94/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.3387 - accuracy: 0.5650
# Epoch 95/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.3247 - accuracy: 0.5750
# Epoch 96/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.3380 - accuracy: 0.5650
# Epoch 97/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.3389 - accuracy: 0.5600
# Epoch 98/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.3428 - accuracy: 0.5600
# Epoch 99/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.3231 - accuracy: 0.5800
# Epoch 100/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.3230 - accuracy: 0.5750
# Epoch 101/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.3198 - accuracy: 0.5800
# Epoch 102/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.3245 - accuracy: 0.5800
# Epoch 103/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.3713 - accuracy: 0.5200
# Epoch 104/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.4117 - accuracy: 0.4850
# Epoch 105/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.4093 - accuracy: 0.4900
# Epoch 106/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.3524 - accuracy: 0.5450
# Epoch 107/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.3292 - accuracy: 0.5650
# Epoch 108/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.3112 - accuracy: 0.5850
# Epoch 109/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.3190 - accuracy: 0.5850
# Epoch 110/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.2859 - accuracy: 0.6250
# Epoch 111/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.2812 - accuracy: 0.6200
# Epoch 112/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.2698 - accuracy: 0.6400
# Epoch 113/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.2438 - accuracy: 0.6650
# Epoch 114/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.2322 - accuracy: 0.6800
# Epoch 115/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.2248 - accuracy: 0.6750
# Epoch 116/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.2564 - accuracy: 0.6500
# Epoch 117/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.2777 - accuracy: 0.6150
# Epoch 118/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.1965 - accuracy: 0.7050
# Epoch 119/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.1940 - accuracy: 0.7150
# Epoch 120/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.1669 - accuracy: 0.7400
# Epoch 121/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.1812 - accuracy: 0.7300
# Epoch 122/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.1547 - accuracy: 0.7550
# Epoch 123/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.1528 - accuracy: 0.7500
# Epoch 124/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.1500 - accuracy: 0.7550
# Epoch 125/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.1494 - accuracy: 0.7600
# Epoch 126/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.1468 - accuracy: 0.7500
# Epoch 127/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.0848 - accuracy: 0.8300
# Epoch 128/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.0303 - accuracy: 0.8800
# Epoch 129/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.0769 - accuracy: 0.8300
# Epoch 130/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.2425 - accuracy: 0.6650
# Epoch 131/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.2449 - accuracy: 0.6550
# Epoch 132/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.2388 - accuracy: 0.6700
# Epoch 133/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.2146 - accuracy: 0.6900
# Epoch 134/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.1211 - accuracy: 0.7800
# Epoch 135/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.0885 - accuracy: 0.8200
# Epoch 136/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.1746 - accuracy: 0.7350
# Epoch 137/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.1503 - accuracy: 0.7550
# Epoch 138/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.1391 - accuracy: 0.7650
# Epoch 139/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.1351 - accuracy: 0.7700
# Epoch 140/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.1339 - accuracy: 0.7650
# Epoch 141/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.1382 - accuracy: 0.7650
# Epoch 142/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.1009 - accuracy: 0.8000
# Epoch 143/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.1023 - accuracy: 0.8050
# Epoch 144/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.1054 - accuracy: 0.8000
# Epoch 145/150
# 13/13 [==============================] - 0s 17ms/step - loss: 1.0963 - accuracy: 0.8100
# Epoch 146/150
# 13/13 [==============================] - 0s 19ms/step - loss: 1.0808 - accuracy: 0.8250
# Epoch 147/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.0760 - accuracy: 0.8300
# Epoch 148/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.1069 - accuracy: 0.8000
# Epoch 149/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.0957 - accuracy: 0.8100
# Epoch 150/150
# 13/13 [==============================] - 0s 18ms/step - loss: 1.0991 - accuracy: 0.8050
# 7/7 [==============================] - 1s 5ms/step - loss: 1.0560 - accuracy: 0.8500
#
# Test accuracy =  0.8500000238418579
# Expected emoji:❤️ prediction: Why do I even try to work things out with him⚾
# Expected emoji:❤️ prediction: What is the matter with them⚾
# Expected emoji:❤️ prediction: What is he thinking⚾
# Expected emoji:❤️ prediction: Everything they say is so stupid⚾
# Expected emoji:❤️ prediction: What is wrong with them⚾
# Expected emoji:❤️ prediction: I have never heard anything stupider than what you just said.⚾
# Expected emoji:⚾ prediction: How can I stop being worried all the time❤️
# Expected emoji:⚾ prediction: When will she return my call❤️
# Expected emoji:⚾ prediction: What are those noises❤️
# Expected emoji:😄 prediction: I am up for the challenge😞
# Expected emoji:😄 prediction: I am very sure about that😞
# Expected emoji:😄 prediction: I believe in the fact that my efforts will pay off soon😞
# Expected emoji:😄 prediction: I am happy with the paper I turned in😞
# Expected emoji:😄 prediction: I am motivated to do my best work on this project😞
# Expected emoji:😄 prediction: I am determined to be the best😞
# Expected emoji:😞 prediction: We are getting married⚾
# Expected emoji:🍴 prediction: This food is extremely bitter😞
# Expected emoji:🍴 prediction: Why can they not just leave me alone❤️
# Expected emoji:🍴 prediction: My favorite football team was eliminated from the playoffs😞
# Expected emoji:🍴 prediction: Why am I so tired all the time⚾
# Expected emoji:🍴 prediction: I have been incredibly unproductive lately⚾
# Expected emoji:🍴 prediction: I wish I could go back to those days⚾
# Expected emoji:🍴 prediction: We are going through a really messy breakup⚾
# Expected emoji:🍴 prediction: Why can I not just be happy⚾
# Expected emoji:🍴 prediction: My favorite TV show just got canceled😞
# Expected emoji:🍴 prediction: Why am I so useless⚾
# Expected emoji:🍴 prediction: Who cares what I think❤️
# Expected emoji:🍴 prediction: I do not have any work to do and I have been having aimless boring days⚾
# Expected emoji:🍴 prediction: I do not have enough time to have fun regularly⚾
# Expected emoji:🍴 prediction: I cannot mend the broken relationship I have with my sister⚾
# I am very happy 😄
# Model: "model_58"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_60 (InputLayer)       [(None, 22)]              0
#
#  embedding_58 (Embedding)    (None, 22, 50)            20000050
#
#  lstm_116 (LSTM)             (None, 22, 128)           91648
#
#  dropout_116 (Dropout)       (None, 22, 128)           0
#
#  lstm_117 (LSTM)             (None, 128)               131584
#
#  dropout_117 (Dropout)       (None, 128)               0
#
#  dense_58 (Dense)            (None, 5)                 645
#
#  activation_58 (Activation)  (None, 5)                 0
#
# =================================================================
# Total params: 20,223,927
# Trainable params: 20,223,927
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 7/7 [==============================] - 3s 19ms/step - loss: 1.6086 - accuracy: 0.1850
# Epoch 2/150
# 7/7 [==============================] - 0s 19ms/step - loss: 1.5965 - accuracy: 0.2650
# Epoch 3/150
# 7/7 [==============================] - 0s 18ms/step - loss: 1.5565 - accuracy: 0.3900
# Epoch 4/150
# 7/7 [==============================] - 0s 18ms/step - loss: 1.5051 - accuracy: 0.3700
# Epoch 5/150
# 7/7 [==============================] - 0s 19ms/step - loss: 1.4408 - accuracy: 0.4700
# Epoch 6/150
# 7/7 [==============================] - 0s 19ms/step - loss: 1.3672 - accuracy: 0.5500
# Epoch 7/150
# 7/7 [==============================] - 0s 18ms/step - loss: 1.3247 - accuracy: 0.5950
# Epoch 8/150
# 7/7 [==============================] - 0s 18ms/step - loss: 1.3859 - accuracy: 0.5200
# Epoch 9/150
# 7/7 [==============================] - 0s 18ms/step - loss: 1.3835 - accuracy: 0.5000
# Epoch 10/150
# 7/7 [==============================] - 0s 19ms/step - loss: 1.3201 - accuracy: 0.5800
# Epoch 11/150
# 7/7 [==============================] - 0s 19ms/step - loss: 1.2351 - accuracy: 0.6850
# Epoch 12/150
# 7/7 [==============================] - 0s 19ms/step - loss: 1.2321 - accuracy: 0.6900
# Epoch 13/150
# 7/7 [==============================] - 0s 20ms/step - loss: 1.1893 - accuracy: 0.7150
# Epoch 14/150
# 7/7 [==============================] - 0s 19ms/step - loss: 1.1933 - accuracy: 0.7200
# Epoch 15/150
# 7/7 [==============================] - 0s 19ms/step - loss: 1.1720 - accuracy: 0.7350
# Epoch 16/150
# 7/7 [==============================] - 0s 19ms/step - loss: 1.1223 - accuracy: 0.7850
# Epoch 17/150
# 7/7 [==============================] - 0s 18ms/step - loss: 1.1193 - accuracy: 0.7800
# Epoch 18/150
# 7/7 [==============================] - 0s 19ms/step - loss: 1.1301 - accuracy: 0.7900
# Epoch 19/150
# 7/7 [==============================] - 0s 17ms/step - loss: 1.1087 - accuracy: 0.8050
# Epoch 20/150
# 7/7 [==============================] - 0s 19ms/step - loss: 1.3679 - accuracy: 0.5350
# Epoch 21/150
# 7/7 [==============================] - 0s 18ms/step - loss: 1.2122 - accuracy: 0.7050
# Epoch 22/150
# 7/7 [==============================] - 0s 19ms/step - loss: 1.2480 - accuracy: 0.6450
# Epoch 23/150
# 7/7 [==============================] - 0s 19ms/step - loss: 1.1572 - accuracy: 0.7550
# Epoch 24/150
# 7/7 [==============================] - 0s 19ms/step - loss: 1.1789 - accuracy: 0.7150
# Epoch 25/150
# 7/7 [==============================] - 0s 19ms/step - loss: 1.1399 - accuracy: 0.7600
# Epoch 26/150
# 7/7 [==============================] - 0s 18ms/step - loss: 1.0978 - accuracy: 0.8000
# Epoch 27/150
# 7/7 [==============================] - 0s 19ms/step - loss: 1.0213 - accuracy: 0.8900
# Epoch 28/150
# 7/7 [==============================] - 0s 19ms/step - loss: 1.0121 - accuracy: 0.8900
# Epoch 29/150
# 7/7 [==============================] - 0s 18ms/step - loss: 1.0068 - accuracy: 0.9000
# Epoch 30/150
# 7/7 [==============================] - 0s 18ms/step - loss: 1.0149 - accuracy: 0.8900
# Epoch 31/150
# 7/7 [==============================] - 0s 18ms/step - loss: 1.0055 - accuracy: 0.9050
# Epoch 32/150
# 7/7 [==============================] - 0s 19ms/step - loss: 1.0008 - accuracy: 0.9100
# Epoch 33/150
# 7/7 [==============================] - 0s 18ms/step - loss: 1.0541 - accuracy: 0.8500
# Epoch 34/150
# 7/7 [==============================] - 0s 19ms/step - loss: 1.0551 - accuracy: 0.8400
# Epoch 35/150
# 7/7 [==============================] - 0s 18ms/step - loss: 1.0287 - accuracy: 0.8800
# Epoch 36/150
# 7/7 [==============================] - 0s 18ms/step - loss: 1.0149 - accuracy: 0.8900
# Epoch 37/150
# 7/7 [==============================] - 0s 18ms/step - loss: 1.0207 - accuracy: 0.8800
# Epoch 38/150
# 7/7 [==============================] - 0s 17ms/step - loss: 1.0223 - accuracy: 0.8800
# Epoch 39/150
# 7/7 [==============================] - 0s 18ms/step - loss: 1.0265 - accuracy: 0.8800
# Epoch 40/150
# 7/7 [==============================] - 0s 19ms/step - loss: 1.0622 - accuracy: 0.8450
# Epoch 41/150
# 7/7 [==============================] - 0s 19ms/step - loss: 1.0724 - accuracy: 0.8350
# Epoch 42/150
# 7/7 [==============================] - 0s 19ms/step - loss: 1.0186 - accuracy: 0.8900
# Epoch 43/150
# 7/7 [==============================] - 0s 18ms/step - loss: 0.9827 - accuracy: 0.9200
# Epoch 44/150
# 7/7 [==============================] - 0s 18ms/step - loss: 1.0083 - accuracy: 0.8950
# Epoch 45/150
# 7/7 [==============================] - 0s 18ms/step - loss: 0.9744 - accuracy: 0.9350
# Epoch 46/150
# 7/7 [==============================] - 0s 18ms/step - loss: 0.9813 - accuracy: 0.9200
# Epoch 47/150
# 7/7 [==============================] - 0s 18ms/step - loss: 0.9658 - accuracy: 0.9400
# Epoch 48/150
# 7/7 [==============================] - 0s 18ms/step - loss: 0.9688 - accuracy: 0.9350
# Epoch 49/150
# 7/7 [==============================] - 0s 19ms/step - loss: 0.9693 - accuracy: 0.9350
# Epoch 50/150
# 7/7 [==============================] - 0s 17ms/step - loss: 0.9655 - accuracy: 0.9400
# Epoch 51/150
# 7/7 [==============================] - 0s 17ms/step - loss: 0.9649 - accuracy: 0.9400
# Epoch 52/150
# 7/7 [==============================] - 0s 18ms/step - loss: 0.9634 - accuracy: 0.9400
# Epoch 53/150
# 7/7 [==============================] - 0s 18ms/step - loss: 1.0361 - accuracy: 0.8650
# Epoch 54/150
# 7/7 [==============================] - 0s 17ms/step - loss: 1.0106 - accuracy: 0.8950
# Epoch 55/150
# 7/7 [==============================] - 0s 20ms/step - loss: 0.9687 - accuracy: 0.9350
# Epoch 56/150
# 7/7 [==============================] - 0s 18ms/step - loss: 0.9642 - accuracy: 0.9400
# Epoch 57/150
# 7/7 [==============================] - 0s 18ms/step - loss: 0.9656 - accuracy: 0.9400
# Epoch 58/150
# 7/7 [==============================] - 0s 19ms/step - loss: 0.9694 - accuracy: 0.9350
# Epoch 59/150
# 7/7 [==============================] - 0s 19ms/step - loss: 0.9601 - accuracy: 0.9450
# Epoch 60/150
# 7/7 [==============================] - 0s 18ms/step - loss: 0.9601 - accuracy: 0.9450
# Epoch 61/150
# 7/7 [==============================] - 0s 18ms/step - loss: 0.9603 - accuracy: 0.9450
# Epoch 62/150
# 7/7 [==============================] - 0s 18ms/step - loss: 0.9600 - accuracy: 0.9450
# Epoch 63/150
# 7/7 [==============================] - 0s 19ms/step - loss: 0.9601 - accuracy: 0.9450
# Epoch 64/150
# 7/7 [==============================] - 0s 19ms/step - loss: 0.9601 - accuracy: 0.9450
# Epoch 65/150
# 7/7 [==============================] - 0s 17ms/step - loss: 0.9592 - accuracy: 0.9450
# Epoch 66/150
# 7/7 [==============================] - 0s 19ms/step - loss: 0.9588 - accuracy: 0.9450
# Epoch 67/150
# 7/7 [==============================] - 0s 19ms/step - loss: 0.9597 - accuracy: 0.9450
# Epoch 68/150
# 7/7 [==============================] - 0s 19ms/step - loss: 0.9643 - accuracy: 0.9400
# Epoch 69/150
# 7/7 [==============================] - 0s 19ms/step - loss: 0.9589 - accuracy: 0.9450
# Epoch 70/150
# 7/7 [==============================] - 0s 18ms/step - loss: 0.9595 - accuracy: 0.9450
# Epoch 71/150
# 7/7 [==============================] - 0s 18ms/step - loss: 0.9628 - accuracy: 0.9450
# Epoch 72/150
# 7/7 [==============================] - 0s 19ms/step - loss: 0.9576 - accuracy: 0.9450
# Epoch 73/150
# 7/7 [==============================] - 0s 18ms/step - loss: 0.9590 - accuracy: 0.9450
# Epoch 74/150
# 7/7 [==============================] - 0s 17ms/step - loss: 0.9926 - accuracy: 0.9100
# Epoch 75/150
# 7/7 [==============================] - 0s 19ms/step - loss: 0.9724 - accuracy: 0.9250
# Epoch 76/150
# 7/7 [==============================] - 0s 18ms/step - loss: 0.9810 - accuracy: 0.9200
# Epoch 77/150
# 7/7 [==============================] - 0s 18ms/step - loss: 0.9762 - accuracy: 0.9300
# Epoch 78/150
# 7/7 [==============================] - 0s 17ms/step - loss: 0.9915 - accuracy: 0.9100
# Epoch 79/150
# 7/7 [==============================] - 0s 19ms/step - loss: 1.0196 - accuracy: 0.8850
# Epoch 80/150
# 7/7 [==============================] - 0s 18ms/step - loss: 0.9761 - accuracy: 0.9300
# Epoch 81/150
# 7/7 [==============================] - 0s 18ms/step - loss: 0.9641 - accuracy: 0.9400
# Epoch 82/150
# 7/7 [==============================] - 0s 18ms/step - loss: 1.0061 - accuracy: 0.8950
# Epoch 83/150
# 7/7 [==============================] - 0s 18ms/step - loss: 0.9676 - accuracy: 0.9400
# Epoch 84/150
# 7/7 [==============================] - 0s 18ms/step - loss: 1.0112 - accuracy: 0.8900
# Epoch 85/150
# 7/7 [==============================] - 0s 18ms/step - loss: 1.0237 - accuracy: 0.8800
# Epoch 86/150
# 7/7 [==============================] - 0s 19ms/step - loss: 1.0933 - accuracy: 0.8100
# Epoch 87/150
# 7/7 [==============================] - 0s 17ms/step - loss: 1.0895 - accuracy: 0.8200
# Epoch 88/150
# 7/7 [==============================] - 0s 18ms/step - loss: 1.0511 - accuracy: 0.8500
# Epoch 89/150
# 7/7 [==============================] - 0s 17ms/step - loss: 1.0127 - accuracy: 0.8900
# Epoch 90/150
# 7/7 [==============================] - 0s 18ms/step - loss: 1.0400 - accuracy: 0.8600
# Epoch 91/150
# 7/7 [==============================] - 0s 18ms/step - loss: 1.0678 - accuracy: 0.8350
# Epoch 92/150
# 7/7 [==============================] - 0s 19ms/step - loss: 1.1082 - accuracy: 0.7900
# Epoch 93/150
# ...
# Epoch 86/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.3563 - accuracy: 0.5400
# Epoch 87/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.3297 - accuracy: 0.5750
# Epoch 88/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.3189 - accuracy: 0.5800
# Epoch 89/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.3001 - accuracy: 0.5850
# Epoch 90/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.2731 - accuracy: 0.6350
# Epoch 91/150
# 4/4 [==============================] - 0s 14ms/step - loss: 1.2647 - accuracy: 0.6400
# Epoch 92/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.4398 - accuracy: 0.4450
# Epoch 93/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.3838 - accuracy: 0.5200
# Epoch 94/150
# 4/4 [==============================] - 0s 13ms/step - loss: 1.3956 - accuracy: 0.5100
# Epoch 95/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.4008 - accuracy: 0.4850
# Epoch 96/150
# 4/4 [==============================] - 0s 13ms/step - loss: 1.3846 - accuracy: 0.5100
# Epoch 97/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.3766 - accuracy: 0.5250
# Epoch 98/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.3721 - accuracy: 0.5300
# Epoch 99/150
# 4/4 [==============================] - 0s 18ms/step - loss: 1.3550 - accuracy: 0.5450
# Epoch 100/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.3579 - accuracy: 0.5450
# Epoch 101/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.3605 - accuracy: 0.5450
# Epoch 102/150
# 4/4 [==============================] - 0s 19ms/step - loss: 1.3648 - accuracy: 0.5350
# Epoch 103/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.3583 - accuracy: 0.5300
# Epoch 104/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.3353 - accuracy: 0.5550
# Epoch 105/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.3333 - accuracy: 0.5550
# Epoch 106/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.3236 - accuracy: 0.5650
# Epoch 107/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.2727 - accuracy: 0.6350
# Epoch 108/150
# 4/4 [==============================] - 0s 14ms/step - loss: 1.3433 - accuracy: 0.5400
# Epoch 109/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.2518 - accuracy: 0.6650
# Epoch 110/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.2229 - accuracy: 0.6850
# Epoch 111/150
# 4/4 [==============================] - 0s 14ms/step - loss: 1.2398 - accuracy: 0.6750
# Epoch 112/150
# 4/4 [==============================] - 0s 14ms/step - loss: 1.2085 - accuracy: 0.7050
# Epoch 113/150
# 4/4 [==============================] - 0s 18ms/step - loss: 1.1923 - accuracy: 0.7150
# Epoch 114/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.2133 - accuracy: 0.6900
# Epoch 115/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.1567 - accuracy: 0.7450
# Epoch 116/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.1064 - accuracy: 0.8000
# Epoch 117/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0365 - accuracy: 0.8700
# Epoch 118/150
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0303 - accuracy: 0.8850
# Epoch 119/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.9976 - accuracy: 0.9150
# Epoch 120/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.0039 - accuracy: 0.9050
# Epoch 121/150
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0084 - accuracy: 0.9000
# Epoch 122/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.0116 - accuracy: 0.8950
# Epoch 123/150
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0025 - accuracy: 0.9050
# Epoch 124/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.0015 - accuracy: 0.9050
# Epoch 125/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.0020 - accuracy: 0.9050
# Epoch 126/150
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0012 - accuracy: 0.9050
# Epoch 127/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0016 - accuracy: 0.9050
# Epoch 128/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.0043 - accuracy: 0.9000
# Epoch 129/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0075 - accuracy: 0.9000
# Epoch 130/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.0092 - accuracy: 0.9000
# Epoch 131/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.9919 - accuracy: 0.9150
# Epoch 132/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.9945 - accuracy: 0.9150
# Epoch 133/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.9814 - accuracy: 0.9250
# Epoch 134/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.9813 - accuracy: 0.9250
# Epoch 135/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.9766 - accuracy: 0.9300
# Epoch 136/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0800 - accuracy: 0.8300
# Epoch 137/150
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0639 - accuracy: 0.8400
# Epoch 138/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.9922 - accuracy: 0.9150
# Epoch 139/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.9719 - accuracy: 0.9350
# Epoch 140/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.9745 - accuracy: 0.9300
# Epoch 141/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.9712 - accuracy: 0.9350
# Epoch 142/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.9661 - accuracy: 0.9400
# Epoch 143/150
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0127 - accuracy: 0.8950
# Epoch 144/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.1498 - accuracy: 0.7500
# Epoch 145/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0373 - accuracy: 0.8700
# Epoch 146/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.0314 - accuracy: 0.8700
# Epoch 147/150
# 4/4 [==============================] - 0s 17ms/step - loss: 1.0471 - accuracy: 0.8550
# Epoch 148/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.0305 - accuracy: 0.8750
# Epoch 149/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.0275 - accuracy: 0.8800
# Epoch 150/150
# 4/4 [==============================] - 0s 17ms/step - loss: 1.3163 - accuracy: 0.5900
# 7/7 [==============================] - 1s 6ms/step - loss: 1.2773 - accuracy: 0.6250
#
# Test accuracy =  0.625
# Expected emoji:❤️ prediction: Why would he waste my time like that🍴
# Expected emoji:❤️ prediction: Who does she think she is🍴
# Expected emoji:❤️ prediction: Why do I even try to work things out with him🍴
# Expected emoji:❤️ prediction: What is the matter with them🍴
# Expected emoji:❤️ prediction: Who cares what they say🍴
# Expected emoji:❤️ prediction: When the hell is she going to get here🍴
# Expected emoji:❤️ prediction: Where on earth is he🍴
# Expected emoji:❤️ prediction: Why are they so late🍴
# Expected emoji:❤️ prediction: What is he thinking🍴
# Expected emoji:❤️ prediction: Why is he so annoying🍴
# Expected emoji:❤️ prediction: Why is their face so irritating🍴
# Expected emoji:❤️ prediction: Why do they always look so smug🍴
# Expected emoji:❤️ prediction: Do they not deserve to be punished🍴
# Expected emoji:❤️ prediction: Everything they say is so stupid🍴
# Expected emoji:❤️ prediction: Do they not realize how awful they are🍴
# Expected emoji:❤️ prediction: When will they understand how much we hate them🍴
# Expected emoji:❤️ prediction: When will they learn that their actions have consequences🍴
# Expected emoji:❤️ prediction: Why can they not mind their own business🍴
# Expected emoji:❤️ prediction: Why are they trying to force their views on me🍴
# Expected emoji:❤️ prediction: Why would they think that is ok to do🍴
# Expected emoji:❤️ prediction: Why are they so infuriating🍴
# Expected emoji:❤️ prediction: Why do they think it is fun to annoy me🍴
# Expected emoji:❤️ prediction: What is wrong with them🍴
# Expected emoji:❤️ prediction: Why even bother🍴
# Expected emoji:❤️ prediction: Why are they so socially inept🍴
# Expected emoji:❤️ prediction: Can they even be reasoned with🍴
# Expected emoji:❤️ prediction: Do they have any redeeming qualities at all🍴
# Expected emoji:❤️ prediction: How could anyone ever love them🍴
# Expected emoji:❤️ prediction: How could anyone ever tolerate them🍴
# Expected emoji:❤️ prediction: Why has someone not told them to stop🍴
# Expected emoji:❤️ prediction: Why can they not tell how much they bother me🍴
# Expected emoji:❤️ prediction: When will they realize how stupid they are🍴
# Expected emoji:❤️ prediction: Who thought it was a good use of space for them to exist🍴
# Expected emoji:❤️ prediction: Why do they not think before they act🍴
# Expected emoji:❤️ prediction: Why can they not just get hit with a truck🍴
# Expected emoji:❤️ prediction: Why should I not shoot them in the face🍴
# Expected emoji:❤️ prediction: Why is she so stubborn🍴
# Expected emoji:❤️ prediction: Why will they not shut up🍴
# Expected emoji:❤️ prediction: Why do they think I care🍴
# Expected emoji:❤️ prediction: I have never heard anything stupider than what you just said.🍴
# Expected emoji:⚾ prediction: Why is he not home yet🍴
# Expected emoji:⚾ prediction: Why can I not find anyone to help me❤️
# Expected emoji:⚾ prediction: Is he dangerous🍴
# Expected emoji:⚾ prediction: Why do I have so much work to do🍴
# Expected emoji:⚾ prediction: When is the next time I will have a chance to relax😄
# Expected emoji:⚾ prediction: Is he going to hurt me🍴
# Expected emoji:⚾ prediction: How can I stop being worried all the time🍴
# Expected emoji:⚾ prediction: Why am I so paranoid🍴
# Expected emoji:⚾ prediction: Will I live to see another day😄
# Expected emoji:⚾ prediction: How do you know he will not come back to hurt me🍴
# Expected emoji:⚾ prediction: When will she return my call🍴
# Expected emoji:⚾ prediction: What if I have a disease🍴
# Expected emoji:⚾ prediction: Is it safe to be here this late🍴
# Expected emoji:⚾ prediction: What are those noises🍴
# Expected emoji:⚾ prediction: What if she embarrasses me in front of everyone🍴
# Expected emoji:⚾ prediction: When will I stop feeling so insecure🍴
# Expected emoji:⚾ prediction: Did I leave the oven on🍴
# Expected emoji:⚾ prediction: Did I say too much🍴
# Expected emoji:⚾ prediction: Did I offend her with my questions🍴
# Expected emoji:⚾ prediction: Why am I so socially awkward🍴
# Expected emoji:⚾ prediction: Did I do something to annoy them🍴
# Expected emoji:⚾ prediction: Why am I so stressed out all the time🍴
# Expected emoji:⚾ prediction: Am I going to oversleep😄
# Expected emoji:⚾ prediction: Is my phone going to die and leave me lost with no connection🍴
# Expected emoji:😞 prediction: That is one of my favorite books😄
# Expected emoji:😞 prediction: We are getting married🍴
# Expected emoji:😞 prediction: I love my parents so much🍴
# Expected emoji:😞 prediction: I already want to revisit this museum as soon as possible😄
# Expected emoji:😞 prediction: My study group for physics is quickly turning into a friend group as well😄
# Expected emoji:😞 prediction: I found 5 dollars that I didnot know I had in my pocket😄
# Expected emoji:😞 prediction: I am so glad that it is a Friday night😄
# Expected emoji:😞 prediction: I am starting to get summer vibes😄
# Expected emoji:😞 prediction: I am finally done paying off all my loans😄
# Expected emoji:🍴 prediction: Some kids in school made fun of my clothes today😞
# Expected emoji:🍴 prediction: My favorite TV show just got canceled😞
# I am very happy 😄
# Model: "model_72"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_74 (InputLayer)       [(None, 22)]              0
#
#  embedding_72 (Embedding)    (None, 22, 50)            20000050
#
#  lstm_144 (LSTM)             (None, 22, 128)           91648
#
#  dropout_144 (Dropout)       (None, 22, 128)           0
#
#  lstm_145 (LSTM)             (None, 128)               131584
#
#  dropout_145 (Dropout)       (None, 128)               0
#
#  dense_72 (Dense)            (None, 5)                 645
#
#  activation_72 (Activation)  (None, 5)                 0
#
# =================================================================
# Total params: 20,223,927
# Trainable params: 20,223,927
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-f62cf9572761> in <module>()
#     155           # Train model
#     156           t0 = time.time()
# --> 157           history = model.fit(X_train_indices, Y_train_oh, epochs=150, batch_size=batch_size, shuffle=True)
#     158           t1 = time.time()
#     159           timeToTrain = t1-t0
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in autograph_handler(*args, **kwargs)
#    1145           except Exception as e:  # pylint:disable=broad-except
#    1146             if hasattr(e, "ag_error_metadata"):
# -> 1147               raise e.ag_error_metadata.to_exception(e)
#    1148             else:
#    1149               raise
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 1021, in train_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 1010, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 1000, in run_step  **
#         outputs = model.train_step(data)
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 860, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 919, in compute_loss
#         y, y_pred, sample_weight, regularization_losses=self.losses)
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/compile_utils.py", line 201, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "/usr/local/lib/python3.7/dist-packages/keras/losses.py", line 141, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "/usr/local/lib/python3.7/dist-packages/keras/losses.py", line 245, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "/usr/local/lib/python3.7/dist-packages/keras/losses.py", line 1863, in sparse_categorical_crossentropy
#         y_true, y_pred, from_logits=from_logits, axis=axis)
#     File "/usr/local/lib/python3.7/dist-packages/keras/backend.py", line 5203, in sparse_categorical_crossentropy
#         labels=target, logits=output)
#
#     ValueError: `labels.shape` must equal `logits.shape` except for the last dimension. Received: labels.shape=(40,) and logits.shape=(8, 5)

# %%
import time
import random
import json
import csv
t0 = time.time()
thresholdTime = 0
outputFile = '/content/drive/MyDrive/Emotional_AI_Chatbot/write_test.csv'
with open(outputFile,"w") as file:
  writer = csv.writer(file)
  writer.writerow(["Loss Function","Batch Size","Optimizer","Test Accuracy"])
  t1 = time.time()
  while t1-t0<12:
    t1 = time.time()
    if (t1-t0)>thresholdTime:
      writer.writerow(["CCE",32,"Adam",0.925])
      # stringData = json.dumps(data)
      # print(stringData)
      # file.write(stringData)
      thresholdTime += 1
